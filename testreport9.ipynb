# %%
import numpy as np
import pandas as pd

# %%
dataframe = pd.read_csv('Custom_Report_PV.csv')

# %%
dataframe.head()
# Out:
#              วันที่โอน FromBank FromBank_BBL FromBank_SCB FromBank_BAY  \
# 0  6/14/2021|6/14/2021  BBL|BBL          1|1          0|0          0|0
# 1  6/30/2021|6/30/2021  BBL|BAY          1|0          0|0          0|1
# 2  6/30/2021|6/30/2021  BBL|SCB          1|0          0|1          0|0
# 3                  NaN      NaN          NaN          NaN          NaN
# 4                  NaN      NaN          NaN          NaN          NaN
#
#   FromBank_Kbank FromBank_TTB FromBank_KTB  FromAccNoBay  \
# 0            0|0          0|0          0|0           NaN
# 1            0|0          0|0          0|0  1.851289e+09
# 2            0|0          0|0          0|0           NaN
# 3            NaN          NaN          NaN           NaN
# 4            NaN          NaN          NaN           NaN
#
#    FromAccNoBay_1850030426  ...  ToAccNoKTB_1950180611  ToAccNoKTB_1956010408  \
# 0                      NaN  ...                    NaN                    NaN
# 1                      0.0  ...                    NaN                    NaN
# 2                      NaN  ...                    NaN                    NaN
# 3                      NaN  ...                    NaN                    NaN
# 4                      NaN  ...                    NaN                    NaN
#
#      ToAccNoSCB  ToAccNoSCB_1173013946  ToAccNoSCB_1172673256    ToAccNoTMB  \
# 0           NaN                    NaN                    NaN           NaN
# 1  1.173014e+09                    1.0                    0.0  1.011103e+09
# 2           NaN                    NaN                    NaN           NaN
# 3           NaN                    NaN                    NaN           NaN
# 4           NaN                    NaN                    NaN           NaN
#
#    ToAccNoTMB_1012199970 ToAccNoTMB_1011102801                Amount  \
# 0                    NaN                   NaN  1850000.00|300000.00
# 1                    0.0                   1.0     1234.00|123333.00
# 2                    NaN                   NaN   3000.00|10000000.00
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
#
#                        RefNo
# 0  BT034-140664|BT035-140664
# 1                 123|123333
# 2     888888888|888888888888
# 3                        NaN
# 4                        NaN
#
# [5 rows x 77 columns]

# %% [markdown]
# วันที่โอน FromBank FromBankAcc  ToBank  ToBankAcc Amount RrfNo

# %%
df = pd.DataFrame(
index=[0, 1, 2,3,4],
columns=['วันที่โอน', 'FormBank', 'AccNo.','ToBank','Accno','Amount','Ref.'])



FB_C = pd.DataFrame(np.array(dataframe['FromBank']
    .map(lambda x:x if (not pd.isna(x)) else 'None')
    .iloc[0]
    .split('|') 
    )
    .reshape(-1, 1),
    columns=['From Bank']
)

FB_C
# Out:
#   From Bank
# 0       BBL
# 1       BBL

# %%
df = pd.DataFrame(


index=[0, 1, 2,3,4],
columns=['Transfer date', 'FormBank', 'AccNo.','ToBank','Accno','Amount','Ref.'])








day_c = pd.DataFrame(np.array(dataframe['วันที่โอน']
    .map(lambda x:x if (not pd.isna(x)) else 'None')
    .iloc[0]
    .split('|') 
    )
    .reshape(-1, 1),
    columns=['วันที่โอน'])

type(day_c.iloc[0][0])
date = day_c.iloc[0][0]
dateS = date.split("/")
dateR = dateS[1]+"/"+dateS[0]+"/"+dateS[2]
dateR

def formatdate(datesting):
    dateS = datesting.split("/")
    dateR = dateS[1]+"/"+dateS[0]+"/"+dateS[2]
    return dateR

day_c = pd.DataFrame(np.array(dataframe['วันที่โอน']
    .map(lambda x:x if (not pd.isna(x)) else 'None')
    .iloc[0]
    .split('|') 
    )
    .reshape(-1, 1),
    columns=['วันที่โอน']   
)['วันที่โอน'].map(formatdate)




FB_C = pd.DataFrame(np.array(dataframe['FromBank']
    .map(lambda x:x if (not pd.isna(x)) else 'None')
    .iloc[0]
    .split('|') 
    )
    .reshape(-1, 1),
    columns=['From Bank']
)



FB_BankAccNo = pd.DataFrame(np.array(dataframe['FromAccNoBBL']
    .map(lambda x:x if (not pd.isna(x)) else 'None')
    .iloc[0]
    .split('|') 
    )
    .reshape(-1, 1),
    columns=['Account No.']
)

To_Bank = pd.DataFrame(np.array(dataframe['ToBank']
    .map(lambda x:x if (not pd.isna(x)) else 'None')
    .iloc[0]
    .split('|') 
    )
    .reshape(-1, 1),
    columns=['To Bank']
)

To_BankNo = pd.DataFrame(np.array(dataframe['ToAccNoBBL']
    .map(lambda x:x if (not pd.isna(x)) else 'None')
    .iloc[0]
    .split('|') 
    )
    .reshape(-1, 1),
    columns=['Account No.']
)


Amount_C = pd.DataFrame(np.array(dataframe['Amount']
    .map(lambda x:x if (not pd.isna(x)) else 'None')
    .iloc[0]
    .split('|') 
    )
    .reshape(-1, 1),
    columns=['Amount']
)

RefNo_C = pd.DataFrame(np.array(dataframe['RefNo']
    .map(lambda x:x if (not pd.isna(x)) else 'None')
    .iloc[0]
    .split('|') 
    )
    .reshape(-1, 1),
    columns=['RefNo']
)

merge = pd.concat([day_c,FB_C,FB_BankAccNo,To_Bank,To_BankNo,Amount_C,RefNo_C], axis=1)



merge.to_csv (r'export_dataframe.csv', index = False, header=True)
print (df)


merge
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'วันที่โอน'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-c73a16b143be> in <module>
#      31     return dateR
#      32
# ---> 33 day_c = pd.DataFrame(np.array(dataframe['วันที่โอน']
#      34     .map(lambda x:x if (not pd.isna(x)) else 'None')
#      35     .iloc[0]
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3453             if self.columns.nlevels > 1:
#    3454                 return self._getitem_multilevel(key)
# -> 3455             indexer = self.columns.get_loc(key)
#    3456             if is_integer(indexer):
#    3457                 indexer = [indexer]
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'วันที่โอน'
