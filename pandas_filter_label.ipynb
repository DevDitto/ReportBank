# %% [markdown]
# # DataFrame.filter() เพื่อเลือก row/column label

# %% [markdown]
# ---
# * author:  [Prasert Kanawattanachai](prasert.k@chula.ac.th)
# * YouTube: https://www.youtube.com/prasertcbs
# * [Chulalongkorn Business School](https://www.cbs.chula.ac.th/en/)
# ---

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('lmD2wFH5vmw', width=720, height=405)

# %%
import pandas as pd

# %%
print(f'pandas version:  {pd.__version__}')
# Out:
# pandas version:  0.25.3

# %%
pd.Timestamp.now()
# Out:
# Timestamp('2020-01-01 14:47:17.491961')

# %% [markdown]
# ## ตัวอย่างที่ 1: ชื่อคอลัมน์ที่เป็นตัวเลข

# %%
url='https://github.com/prasertcbs/basic-dataset/raw/master/iphone%20sales%20in%20asia.xlsx'
df=pd.read_excel(url, index_col='Geography')
df
# Out:
#                 2010     2011      2012      2013        2014      2015  \
# Geography
# China        3612500  9704700  17192900  22166100  32169800.0  49828900
# Hong Kong     800000  1500000   2297900   3110000   3637300.0   3350000
# India          44500   268800    453500   1540300   1340100.0   2249900
# Indonesia     102900   238800    478300    810400    940500.0   1137600
# Japan        5066300  7266000  10535700  13801600  14679700.0  15200500
# Malaysia      184600   441000    759400   1222700   1461900.0   1736800
# Philippines   223400   326500    416300    608800    621300.0    637100
# Singapore     264900   508400    784200    908900   1067700.0   1105500
# South Korea  1632000  2492500    755900   1490600   2067300.0   2669800
# Taiwan        232900   642800    787800   1121100   1379800.0   1618500
# Thailand      214800   471500    813700   1658600   1745100.0   1850700
# Vietnam        95500   166100    434800    764700   1213500.0   1785800
#
# ...

# %%
df.columns
# Out:
# Int64Index([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], dtype='int64')

# %%
df[2015]
# Out:
# Geography
# China          49828900
# Hong Kong       3350000
# India           2249900
# Indonesia       1137600
# Japan          15200500
# Malaysia        1736800
# Philippines      637100
# Singapore       1105500
# South Korea     2669800
# Taiwan          1618500
# Thailand        1850700
# Vietnam         1785800
# Name: 2015, dtype: int64

# %%
df[2015:]
# Out:
# Empty DataFrame
# Columns: [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
# Index: []

# %%
df.columns >= 2015
# Out:
# array([False, False, False, False, False,  True,  True,  True,  True,
#         True])

# %%
df[df.columns[df.columns >= 2015]] # boolean index
# Out:
#                  2015      2016      2017      2018      2019
# Geography
# China        49828900  44357000  41252000  36921000  32490500
# Hong Kong     3350000   3000000   2809200   2543200   2240500
# India         2249900   3549000   5015700   6335500   5951900
# Indonesia     1137600   1103300   1252400    828300    799900
# Japan        15200500  15732500  15685300  15552600  15241500
# Malaysia      1736800   1597900   1489700   1360000   1280100
# Philippines    637100    580700    485700    470700    447000
# Singapore     1105500   1099400   1021000    974100    954600
# South Korea   2669800   3163100   3289600   3455100   3512100
# Taiwan        1618500   1563800   1482500   1415100   1457800
# Thailand      1850700   1908000   1896100   1776100   1720000
# Vietnam       1785800   1770000   1760000   1643600   1624600

# %%
df.filter(regex='[6-9]$', axis=1)
# Out:
#                  2016      2017      2018      2019
# Geography
# China        44357000  41252000  36921000  32490500
# Hong Kong     3000000   2809200   2543200   2240500
# India         3549000   5015700   6335500   5951900
# Indonesia     1103300   1252400    828300    799900
# Japan        15732500  15685300  15552600  15241500
# Malaysia      1597900   1489700   1360000   1280100
# Philippines    580700    485700    470700    447000
# Singapore     1099400   1021000    974100    954600
# South Korea   3163100   3289600   3455100   3512100
# Taiwan        1563800   1482500   1415100   1457800
# Thailand      1908000   1896100   1776100   1720000
# Vietnam       1770000   1760000   1643600   1624600

# %%
df.filter(regex='(0|3|5)$', axis=1)
# Out:
#                 2010      2013      2015
# Geography
# China        3612500  22166100  49828900
# Hong Kong     800000   3110000   3350000
# India          44500   1540300   2249900
# Indonesia     102900    810400   1137600
# Japan        5066300  13801600  15200500
# Malaysia      184600   1222700   1736800
# Philippines   223400    608800    637100
# Singapore     264900    908900   1105500
# South Korea  1632000   1490600   2669800
# Taiwan        232900   1121100   1618500
# Thailand      214800   1658600   1850700
# Vietnam        95500    764700   1785800

# %%
df.filter(items=[2015, 2019], axis=1)
# Out:
#                  2015      2019
# Geography
# China        49828900  32490500
# Hong Kong     3350000   2240500
# India         2249900   5951900
# Indonesia     1137600    799900
# Japan        15200500  15241500
# Malaysia      1736800   1280100
# Philippines    637100    447000
# Singapore     1105500    954600
# South Korea   2669800   3512100
# Taiwan        1618500   1457800
# Thailand      1850700   1720000
# Vietnam       1785800   1624600

# %%
df.filter(regex='Thailand', axis=0)
# Out:
#              2010    2011    2012     2013       2014     2015     2016  \
# Geography
# Thailand   214800  471500  813700  1658600  1745100.0  1850700  1908000
#
#               2017     2018     2019
# Geography
# Thailand   1896100  1776100  1720000

# %%
df.filter(regex='Thailand|Vietnam', axis=0)
# Out:
#              2010    2011    2012     2013       2014     2015     2016  \
# Geography
# Thailand   214800  471500  813700  1658600  1745100.0  1850700  1908000
# Vietnam     95500  166100  434800   764700  1213500.0  1785800  1770000
#
#               2017     2018     2019
# Geography
# Thailand   1896100  1776100  1720000
# Vietnam    1760000  1643600  1624600

# %%
df.filter(regex='^(T|V|C)', axis=0)
# Out:
#               2010     2011      2012      2013        2014      2015  \
# Geography
# China      3612500  9704700  17192900  22166100  32169800.0  49828900
# Taiwan      232900   642800    787800   1121100   1379800.0   1618500
# Thailand    214800   471500    813700   1658600   1745100.0   1850700
# Vietnam      95500   166100    434800    764700   1213500.0   1785800
#
#                2016      2017      2018      2019
# Geography
# China      44357000  41252000  36921000  32490500
# Taiwan      1563800   1482500   1415100   1457800
# Thailand    1908000   1896100   1776100   1720000
# Vietnam     1770000   1760000   1643600   1624600

# %%
df.filter(regex='(d|a)$', axis=0)
# Out:
#                 2010     2011      2012      2013        2014      2015  \
# Geography
# China        3612500  9704700  17192900  22166100  32169800.0  49828900
# India          44500   268800    453500   1540300   1340100.0   2249900
# Indonesia     102900   238800    478300    810400    940500.0   1137600
# Malaysia      184600   441000    759400   1222700   1461900.0   1736800
# South Korea  1632000  2492500    755900   1490600   2067300.0   2669800
# Thailand      214800   471500    813700   1658600   1745100.0   1850700
#
#                  2016      2017      2018      2019
# Geography
# China        44357000  41252000  36921000  32490500
# India         3549000   5015700   6335500   5951900
# Indonesia     1103300   1252400    828300    799900
# Malaysia      1597900   1489700   1360000   1280100
# South Korea   3163100   3289600   3455100   3512100
# Thailand      1908000   1896100   1776100   1720000

# %%
df.filter(regex='sia$', axis=0)
# Out:
#              2010    2011    2012     2013       2014     2015     2016  \
# Geography
# Indonesia  102900  238800  478300   810400   940500.0  1137600  1103300
# Malaysia   184600  441000  759400  1222700  1461900.0  1736800  1597900
#
#               2017     2018     2019
# Geography
# Indonesia  1252400   828300   799900
# Malaysia   1489700  1360000  1280100

# %%
df.filter(regex='sia$', axis=0).filter(regex='[5-9]$', axis=1)
# Out:
#               2015     2016     2017     2018     2019
# Geography
# Indonesia  1137600  1103300  1252400   828300   799900
# Malaysia   1736800  1597900  1489700  1360000  1280100

# %% [markdown]
# ## ตัวอย่าง 2

# %%
ds=pd.read_table('https://github.com/prasertcbs/tutorial/raw/master/score_a.tsv',
                index_col='studentid')
ds
# Out:
#            math1  eng1  sci1  math2  eng2  sci2  math3  eng3  sci3
# studentid
# C215          10     9     4      7     5     6      7     6     9
# C211           6    10     8     10     6     7      6     5    10
# C305           8     5     4      6     3     7     10    10     5
# B344           4     8     7      6     8     7      4    10     8
# A312           9     8    10      8     6     9      5    10     9
# B243           4     6     6      6     5     3      8     6     6
# B304           4     4     4      6     7     4      7     9     6
# A349           4     4     7      7     6     6      9     5     8
# C409           4     4     4      8     6     8     10     9     6
# C446           4    10     4      3     5     4     10     7     7
# A398           4     6     8      5     5     4      7     5     8

# %%
ds.filter(regex='^math', axis=1)
# Out:
#            math1  math2  math3
# studentid
# C215          10      7      7
# C211           6     10      6
# C305           8      6     10
# B344           4      6      4
# A312           9      8      5
# B243           4      6      8
# B304           4      6      7
# A349           4      7      9
# C409           4      8     10
# C446           4      3     10
# A398           4      5      7

# %%
ds.filter(regex='2$', axis=1)
# Out:
#            math2  eng2  sci2
# studentid
# C215           7     5     6
# C211          10     6     7
# C305           6     3     7
# B344           6     8     7
# A312           8     6     9
# B243           6     5     3
# B304           6     7     4
# A349           7     6     6
# C409           8     6     8
# C446           3     5     4
# A398           5     5     4

# %%
ds.filter(regex='^(math|eng)', axis=1)
# Out:
#            math1  eng1  math2  eng2  math3  eng3
# studentid
# C215          10     9      7     5      7     6
# C211           6    10     10     6      6     5
# C305           8     5      6     3     10    10
# B344           4     8      6     8      4    10
# A312           9     8      8     6      5    10
# B243           4     6      6     5      8     6
# B304           4     4      6     7      7     9
# A349           4     4      7     6      9     5
# C409           4     4      8     6     10     9
# C446           4    10      3     5     10     7
# A398           4     6      5     5      7     5

# %%
ds.filter(regex='^(math|eng)2', axis=1)
# Out:
#            math2  eng2
# studentid
# C215           7     5
# C211          10     6
# C305           6     3
# B344           6     8
# A312           8     6
# B243           6     5
# B304           6     7
# A349           7     6
# C409           8     6
# C446           3     5
# A398           5     5

# %%
ds.columns.str.match('^(math|eng)2')
# Out:
# array([False, False, False,  True,  True, False, False, False, False])

# %%
ds[ds.columns[ds.columns.str.match('^(math|eng)2')]]
# Out:
#            math2  eng2
# studentid
# C215           7     5
# C211          10     6
# C305           6     3
# B344           6     8
# A312           8     6
# B243           6     5
# B304           6     7
# A349           7     6
# C409           8     6
# C446           3     5
# A398           5     5

# %%
ds.filter(regex='^(math|eng)2', axis=1).filter(regex='^A', axis=0)
# Out:
#            math2  eng2
# studentid
# A312           8     6
# A349           7     6
# A398           5     5
